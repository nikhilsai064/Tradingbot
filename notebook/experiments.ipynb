# %%
import os
import sys

# %%
class TradingBotException(Exception):
    def __init__(self,error_message,error_details:sys):
        self.error_message  = error_message
        _,_,exc_tb = error_details.exc_info()

        self.lineno=exc_tb.tb_lineno
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        

    def __str__(self,error_message,error_details:sys):
        return "Error occured in python script name [{0}] line number [{1}] error message [{2}]".format(
        self.file_name, self.lineno, str(self.error_message))

# %%
obj=TradingBotException()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 obj=TradingBotException()
#
# TypeError: TradingBotException.__init__() missing 2 required positional arguments: 'error_message' and 'error_details'

# %%
try:
    a=1/0
    print("This will not be printed",a)
except Exception as e:
    raise TradingBotException(e,sys)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 try:
# ----> 2     a=1/0
#       3     print("This will not be printed",a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# TradingBotException                       Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 5
#       4 except Exception as e:
# ----> 5     raise TradingBotException(e,sys)
#
# <class 'str'>: (<class 'TypeError'>, TypeError("TradingBotException.__str__() missing 2 required positional arguments: 'error_message' and 'error_details'"))
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File c:\Users\pachi\anaconda3\envs\tradingbot\Lib\site-packages\IPython\core\interactiveshell.py:2212, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2209         traceback.print_exc()
#    2210         return None
# -> 2212     self._showtraceback(etype, value, stb)
#    2213 if self.call_pdb:
#    2214     # drop into debugger
#    2215     self.debugger(force=True)
#
# File c:\Users\pachi\anaconda3\envs\tradingbot\Lib\site-packages\ipykernel\zmqshell.py:673, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     667 sys.stdout.flush()
#     668 sys.stderr.flush()
#     670 exc_content = {
#     671     "traceback": stb,
#     672     "ename": str(etype.__name__),
# --> 673     "evalue": str(evalue),
#     674 }
#     676 dh = self.displayhook
#     677 # Send exception info over pub socket for other clients than the caller
#     678 # to pick up
#
# TypeError: TradingBotException.__str__() missing 2 required positional arguments: 'error_message' and 'error_details'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\pachi\anaconda3\envs\tradingbot\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File c:\Users\pachi\anaconda3\envs\tradingbot\Lib\site-packages\IPython\core\interactiveshell.py:3419, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3414     self.history_manager.store_output(execution_count)
#    3415     if result.error_in_exec:
#    3416         # Store formatted traceback and error details
#    3417         self.history_manager.exceptions[
#    3418             execution_count
# -> 3419         ] = self._format_exception_for_storage(result.error_in_exec)
#    3421 return result
#
# File c:\Users\pachi\anaconda3\envs\tradingbot\Lib\site-packages\IPython\core\interactiveshell.py:3476, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3472         except Exception:
#    3473             # In case formatting fails, fallback to Python's built-in formatting.
#    3474             stb = traceback.format_exception(etype, evalue, tb)
# -> 3476 return {"ename": etype.__name__, "evalue": str(evalue), "traceback": stb}
#
# TypeError: TradingBotException.__str__() missing 2 required positional arguments: 'error_message' and 'error_details'

# %%
import logging

# %%
logging.getLogger("my_agentic_app")
# Out:
# <Logger my_agentic_app (WARNING)>

# %%
import sys

# %%
class TradingBotException(Exception):
    def __init__(self):
        print("this message from init")
        
    def __str__(self):
        print("this message from str")
        return ""
        
    def __repr__(self):
        print("this message from repr")
        return ""

# %%
obj=TradingBotException()
# Out:
# this message from init

# %%
print(obj)
# Out:
# this message from str

# %%
obj
# Out:
# this message from repr

# %%
class TradingBotException(Exception):
    def __init__(self,error_message,error_details_using_sys:sys):
        
        self.error_message = error_message
        _,_,exc_tb = error_details_using_sys.exc_info()
        
        self.lineno=exc_tb.tb_lineno
        self.file_name=exc_tb.tb_frame.f_code.co_filename 
    
    def __str__(self):
        return "Error occured in python script name [{0}] line number [{1}] error message [{2}]".format(
        self.file_name, self.lineno, str(self.error_message))

# %%
def test(message):
    print("add"+message)
    print(sys.exc_info())
    print(sys.exc_info())

# %%
test("hi hi hi")
# Out:
# addhi hi hi
# (None, None, None)
# (None, None, None)

# %%
try:
    a=1/0
    print("This will not be printed",a)
except Exception as e:
    raise TradingBotException(e,sys)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 try:
# ----> 2     a=1/0
#       3     print("This will not be printed",a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# TradingBotException                       Traceback (most recent call last)
# Cell In[18], line 5
#       3     print("This will not be printed",a)
#       4 except Exception as e:
# ----> 5     raise TradingBotException(e,sys)
#
# TradingBotException: Error occured in python script name [C:\Users\pachi\AppData\Local\Temp\ipykernel_26936\3076653162.py] line number [2] error message [division by zero]

# %%
import logging
import os
from datetime import datetime

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

# %%
logs_path = os.path.join(os.getcwd(), "logs")

# %%
os.makedirs(logs_path, exist_ok=True)

# %%
LOG_FILE_PATH = os.path.join(logs_path, LOG_FILE)

# %%
logger=logging.getLogger("my_agentic_app")

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(lineno)d %(name)s - %(levelname)s - %(message)s",
    level=logging.INFO,
)

# %%
logger.info("this is my testing message")

# %%
print("musicapp")

# %%
pritn("hello")
pritn("hi")
